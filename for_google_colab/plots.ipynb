# %%
import pandas as pd

# %%
data = pd.read_csv('train_epochs.csv')

# %%
data
# Out:
#     Epoch      Loss       BAC
# 0       1  0.692389  0.503606
# 1       2  0.690053  0.527644
# 2       3  0.685837  0.556490
# 3       4  0.674675  0.667067
# 4       5  0.694560  0.526442
# ..    ...       ...       ...
# 95     96  0.680028  0.593750
# 96     97  0.672417  0.575721
# 97     98  0.685390  0.530048
# 98     99  0.662706  0.503606
# 99    100  0.666239  0.557692
#
# [100 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
def plot(data):
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))
    
    ax1.plot(data['Epoch'], data['Loss'], marker='o', color='b')
    ax1.set_title('Loss vs Epochs')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Loss')
    
    ax2.plot(data['Epoch'], data['BAC'], marker='o', color='r')
    ax2.set_title('BAC vs Epochs')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('BAC')
    
    plt.tight_layout()
    plt.show()

# %%
def plot_on_one(data):
    fig, ax = plt.subplots(figsize=(10, 8))
    
    ax.plot(data['Epoch'], data['Loss'], marker='o', color='b', label='Loss')
    ax.plot(data['Epoch'], data['BAC'], marker='o', color='r', label='BAC')
    ax.set_title('Loss and BAC vs Epochs')
    ax.set_xlabel('Epochs')
    ax.set_ylabel('Value')
    
    ax.legend()
    
    plt.tight_layout()
    plt.show()

# %%
plot_on_one(data)
