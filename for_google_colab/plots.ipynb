# %%
import pandas as pd

# %%
data = pd.read_csv('train_epochs_8.csv')

# %%
data
# Out:
#     Epoch      Loss       BAC
# 0       1  0.699977  0.492788
# 1       2  0.684622  0.599760
# 2       3  0.665465  0.686298
# 3       4  0.709077  0.501202
# 4       5  0.653548  0.733173
# ..    ...       ...       ...
# 95     96  0.570696  0.698317
# 96     97  0.511426  0.721154
# 97     98  0.440683  0.814904
# 98     99  0.558936  0.735577
# 99    100  0.585237  0.677885
#
# [100 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
def plot(data):
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))
    
    ax1.plot(data['Epoch'], data['Loss'], marker='o', color='b')
    ax1.set_title('Loss vs Epochs')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Loss')
    
    ax2.plot(data['Epoch'], data['BAC'], marker='o', color='r')
    ax2.set_title('BAC vs Epochs')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('BAC')
    
    plt.tight_layout()
    plt.show()

# %%
def plot_on_one(data):
    fig, ax = plt.subplots(figsize=(10, 8))
    
    ax.plot(data['Epoch'], data['Loss'], marker='o', color='b', label='Loss')
    ax.plot(data['Epoch'], data['BAC'], marker='o', color='r', label='BAC')
    ax.set_title('Loss and BAC vs Epochs - 8 patches')
    ax.set_xlabel('Epochs')
    ax.set_ylabel('Value')
    
    ax.legend()
    
    plt.tight_layout()
    plt.show()

# %%
plot_on_one(data)

# %%
data = pd.read_csv('train_epochs.csv')

# %%
import matplotlib.pyplot as plt
def plot(data):
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))
    
    ax1.plot(data['Epoch'], data['Loss'], marker='o', color='b')
    ax1.set_title('Loss vs Epochs')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Loss')
    
    ax2.plot(data['Epoch'], data['BAC'], marker='o', color='r')
    ax2.set_title('BAC vs Epochs')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('BAC')
    
    plt.tight_layout()
    plt.show()

# %%
def plot_on_one(data):
    fig, ax = plt.subplots(figsize=(10, 8))
    
    ax.plot(data['Epoch'], data['Loss'], marker='o', color='b', label='Loss')
    ax.plot(data['Epoch'], data['BAC'], marker='o', color='r', label='BAC')
    ax.set_title('Loss and BAC vs Epochs - 8 patches')
    ax.set_xlabel('Epochs')
    ax.set_ylabel('Value')
    
    ax.legend()
    
    plt.tight_layout()
    plt.show()
